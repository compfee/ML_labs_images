# %% [markdown]
# Object Detection

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
#!pip install -q tensorflow==2.8.0
# !git clone https://github.com/dvolchek/YOLOv3-TensorFlow-2.x.git
# %cd YOLOv3-TensorFlow-2.x
# !wget -P model_data https://pjreddie.com/media/files/yolov3.weights
# Out:
# Cloning into 'YOLOv3-TensorFlow-2.x'...
# remote: Enumerating objects: 81, done.
# remote: Counting objects: 100% (81/81), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 81 (delta 31), reused 23 (delta 1), pack-reused 0
# Unpacking objects: 100% (81/81), 42.10 MiB | 10.75 MiB/s, done.
# /content/YOLOv3-TensorFlow-2.x
# --2023-05-28 15:18:01--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘model_data/yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  61.9MB/s    in 4.1s
#
# 2023-05-28 15:18:05 (57.7 MB/s) - ‘model_data/yolov3.weights’ saved [248007048/248007048]

# %%
import detection_demo
detection_demo.detect('/content/42.jpg')
from PIL import Image
image = Image.open('/content/detected.jpg')
image
# Out:
# 1/1 [==============================] - 4s 4s/step
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=700x479 at 0x7FD3E045A9B0>
